# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import xarray as xa
import h5py    
import pandas as pd

# %%
file_name = 'data.h5' 
f1 = h5py.File('/home/dm/uni/ccees/seminar/analysis/' + file_name, 'r+')

# %%
f1
# Out:
# <HDF5 file "data.h5" (mode r+)>

# %%
print(list(f1.keys()))
# Out:
# ['MyFancySeirModel']

# %%
ref_data = f1['MyFancySeirModel']['SEIR_reference']

# %%
f1['MyFancySeirModel']['g_static']
# Out:
# <HDF5 group "/MyFancySeirModel/g_static" (9 members)>

# %%
    shape = f1['MyFancySeirModel']['g_static']['D'].shape

comps = ['D', 'E', 'I', 'N', 'R', 'S']
comp_data = np.empty((shape[0], shape[1],  len(comps)))

# %%
for (i, comp) in enumerate(comps):
    comp_data[:, :, i] = f1['MyFancySeirModel']['g_static'][comp]

# %%
ref_data.shape
# Out:
# (4001, 5)

# %%
comp_data_summed = np.sum(comp_data, axis=1)

# %%
fig, ax = plt.subplots(figsize=(10,10))
for (i, comp) in enumerate(comps):
    ax.plot(comp_data_summed[:, i], label=comp)
for j in range(5):
    ax.plot(ref_data[:, j], '--')

ax.legend()

plt.show()
